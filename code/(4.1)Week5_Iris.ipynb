# %% [markdown]
# ## 인공지능 개론 5주차

# %% [markdown]
# ### IRIS 데이터 실습
# 0. 레이블을 숫자로 변환
# 1. 독립변수, 종속변수 분리
# 2. y를 one-hot-encoding + numpy로 변환
# 3. x를 numpy로 변환
# 4. 모델에서 입력/출력층 갯수 수정 (X_train.shape[1])
# 5. 분류에 따라 마지막 레이어의 함수(softmax,sigmoid), 손실함수(BCE,CCE) 둘 중 하나로 수정

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

file_path ="/Users/yunseongmun/Documents/Ai_Lecture/data/iris/iris.data"
headers = ['sepal length in cm', 'sepal width in cm', 'petal length in cm','petal width in cm', 'class']

df = pd.read_csv(file_path, header=None, names=headers)
df
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# 4                  0.2     Iris-setosa
# ..                 ...             ...
# 145                2.3  Iris-virginica
# 146                1.9  Iris-virginica
# 147                2.0  Iris-virginica
# 148                2.3  Iris-virginica
# 149                1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# 컬렴명 확인
df.columns
# Out:
# Index(['sepal length in cm', 'sepal width in cm', 'petal length in cm',
#        'petal width in cm', 'class'],
#       dtype='object')

# %%
# 레이블 갯수 확인 (숫자)
df['class'].value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ### 0. 레이블을 숫자로 변환

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
label = LabelEncoder()
df['class']=label.fit_transform(df['class'])
df.head()
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal width in cm  class
# 0                0.2      0
# 1                0.2      0
# 2                0.2      0
# 3                0.2      0
# 4                0.2      0

# %% [markdown]
# ### 1. 독립변수, 종속변수 분리

# %%
x=df.drop('class',axis=1)
x
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.2
# ..                 ...
# 145                2.3
# 146                1.9
# 147                2.0
# 148                2.3
# 149                1.8
#
# [150 rows x 4 columns]

# %%
y=df['class']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: class, Length: 150, dtype: int64

# %% [markdown]
# ### 2. y를 one-hot-encoding + numpy로 변환

# %%
Y = pd.get_dummies(y).values
Y
# Out:
# array([[ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True]])

# %% [markdown]
# ### 3. x를 numpy로 변환

# %%
X = x.values
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0) 
print(X.shape, Y.shape, X_train.shape, Y_train.shape)
# Out:
# (150, 4) (150, 3) (120, 4) (120, 3)

# %%
X_train.shape[1]
# Out:
# 4

# %% [markdown]
# ### 4. 모델에서 입력/출력층 갯수 수정

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(10,input_shape=(X_train.shape[1],),activation='sigmoid'))
model.add(Dense(8,activation='sigmoid'))
model.add(Dense(6,activation='sigmoid'))
model.add(Dense(3,activation='softmax'))

model.compile(Adam(lr=0.04),'categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                50
#
#  dense_5 (Dense)             (None, 8)                 88
#
#  dense_6 (Dense)             (None, 6)                 54
#
#  dense_7 (Dense)             (None, 3)                 21
#
# =================================================================
# Total params: 213
# Trainable params: 213
# Non-trainable params: 0
# _________________________________________________________________
# /Users/yunseongmun/anaconda3/lib/python3.11/site-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
model_history=model.fit(x=X_train, y=Y_train, epochs=30, batch_size=32,validation_split= 0.1)
Y_pred = model.predict(X_test)

y_test_class = np.argmax(Y_test,axis=1)
y_pred_class = np.argmax(Y_pred,axis=1)
# Out:
# Epoch 1/30
# 1/4 [======>.......................] - ETA: 0s - loss: 1.2922 - accuracy: 0.3750
# 2024-04-01 11:23:47.621196: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 4/4 [==============================] - 0s 30ms/step - loss: 1.2017 - accuracy: 0.3056 - val_loss: 1.1835 - val_accuracy: 0.1667
# Epoch 2/30
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0904 - accuracy: 0.3889 - val_loss: 1.2748 - val_accuracy: 0.1667
# Epoch 3/30
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0786 - accuracy: 0.3889 - val_loss: 1.1265 - val_accuracy: 0.5833
# Epoch 4/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9972 - accuracy: 0.7037 - val_loss: 0.9528 - val_accuracy: 0.5833
# Epoch 5/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8863 - accuracy: 0.7037 - val_loss: 0.8353 - val_accuracy: 0.5833
# Epoch 6/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7498 - accuracy: 0.7037 - val_loss: 0.6973 - val_accuracy: 0.5833
# Epoch 7/30
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6296 - accuracy: 0.7407 - val_loss: 0.5859 - val_accuracy: 0.7500
# Epoch 8/30
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5464 - accuracy: 0.7500 - val_loss: 0.5316 - val_accuracy: 0.5833
# Epoch 9/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4977 - accuracy: 0.7963 - val_loss: 0.4800 - val_accuracy: 0.6667
# Epoch 10/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4532 - accuracy: 0.8056 - val_loss: 0.4054 - val_accuracy: 0.8333
# Epoch 11/30
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4185 - accuracy: 0.9167 - val_loss: 0.3569 - val_accuracy: 0.9167
# Epoch 12/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3780 - accuracy: 0.9352 - val_loss: 0.3278 - val_accuracy: 0.9167
# Epoch 13/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3382 - accuracy: 0.9630 - val_loss: 0.2760 - val_accuracy: 1.0000
# Epoch 14/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3239 - accuracy: 0.9444 - val_loss: 0.2735 - val_accuracy: 0.9167
# Epoch 15/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2634 - accuracy: 0.9630 - val_loss: 0.2295 - val_accuracy: 1.0000
# Epoch 16/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2462 - accuracy: 0.9630 - val_loss: 0.3201 - val_accuracy: 0.8333
# Epoch 17/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2501 - accuracy: 0.9537 - val_loss: 0.1993 - val_accuracy: 0.9167
# Epoch 18/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1842 - accuracy: 0.9630 - val_loss: 0.1750 - val_accuracy: 0.9167
# Epoch 19/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1798 - accuracy: 0.9722 - val_loss: 0.2301 - val_accuracy: 0.9167
# Epoch 20/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2369 - accuracy: 0.9074 - val_loss: 0.1152 - val_accuracy: 1.0000
# Epoch 21/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1708 - accuracy: 0.9444 - val_loss: 0.1546 - val_accuracy: 0.9167
# Epoch 22/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1827 - accuracy: 0.9444 - val_loss: 0.2609 - val_accuracy: 0.9167
# Epoch 23/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1469 - accuracy: 0.9537 - val_loss: 0.0750 - val_accuracy: 1.0000
# Epoch 24/30
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1440 - accuracy: 0.9630 - val_loss: 0.1794 - val_accuracy: 0.9167
# Epoch 25/30
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1283 - accuracy: 0.9537 - val_loss: 0.1256 - val_accuracy: 0.9167
# Epoch 26/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1275 - accuracy: 0.9537 - val_loss: 0.2018 - val_accuracy: 0.9167
# Epoch 27/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0985 - accuracy: 0.9815 - val_loss: 0.0547 - val_accuracy: 1.0000
# Epoch 28/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1186 - accuracy: 0.9630 - val_loss: 0.1197 - val_accuracy: 0.9167
# Epoch 29/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0922 - accuracy: 0.9722 - val_loss: 0.1013 - val_accuracy: 0.9167
# Epoch 30/30
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0851 - accuracy: 0.9815 - val_loss: 0.0622 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 37ms/step
